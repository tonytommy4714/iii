# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/index.html')
soup = BeautifulSoup(res.text,"html.parser")
aaa="a.board div"
new=soup.select(aaa)
for title in new:
    print(title)
# Out:
# <div class="board-name">Gossiping</div>
# <div class="board-nuser"><span class="hl f6">13563</span></div>
# <div class="board-class">綜合</div>
# <div class="board-title">◎[八卦板] </div>
# <div class="board-name">NBA</div>
# <div class="board-nuser"><span class="hl f4">5106</span></div>
# <div class="board-class">籃球</div>
# <div class="board-title">◎[NBA]    超賽騎士/火箭勇士</div>
# <div class="board-name">MobileComm</div>
# <div class="board-nuser"><span class="hl f1">4033</span></div>
# <div class="board-class">資訊</div>
# <div class="board-title">◎[通訊] 快閃吃到飽文章請先洽置底</div>
# <div class="board-name">Stock</div>
# <div class="board-nuser"><span class="hl f1">2766</span></div>
# <div class="board-class">學術</div>
# <div class="board-title">◎[股板] 推發文前請閱讀置底板規</div>
# <div class="board-name">C_Chat</div>
# <div class="board-nuser"><span class="hl f1">2269</span></div>
# <div class="board-class">閒談</div>
# <div class="board-title">◎[希洽] 草日月希洽</div>
# <div class="board-name">Baseball</div>
# ...

# %%
res = requests.get('http://www.58b.tv/')
soup = BeautifulSoup(res.text,"html.parser")

aaa="div.hbd11.ssv "
new=soup.select(aaa)
for title in new:
    print(title.text)
# Out:
# 海賊王/航海東京喰種 第刀劍神域 外食戟之靈 第七原罪 第2季我的英雄學院火影忍者 博Running Man(惡魔小姐：人西部世界 第1006的房客棒球大聯盟 全職高手 特神盾局特工 海賊王/航海黑色五葉草鬥破蒼穹 第飛虎：潛行極行騙天下JP大叔的愛

# %%
res = requests.get('https://www.tibame.com/')
soup = BeautifulSoup(res.text,"html.parser")

aaa="div.card-body "
new=soup.select(aaa)
for title in new:
    print(title.text)
# Out:
# 直播課程GA網站數據分析-國際認證通關密技NT$8,888 NT$2,638
# 直播課程不寫程式的大數據分析師I：數據分析之王-超強exc...NT$5,888 NT$2,388
# WordPress視覺排版設計超入門：CSS與HT...NT$3,388 NT$1,930
# 直播課程[盧瑞山] 區塊鏈2.0 -精通以太坊與智能合約NT$7,500 NT$4,875
# 直播課程預見商機:市場分析研究與行銷應用NT$4,980 NT$1,888
# 直播課程【錄播】提升轉換率！Landing Page與Go...NT$12,800 NT$12,800
# 直播課程尹相志深度學習實戰  八週直播課程大師跨海教學NT$16,000 NT$13,000
# 直播課程地表最好懂的Python網路爬蟲 零基礎也能學會 ...NT$9,000 NT$4,500

# %%
res = requests.get('https://www.591.com.tw/')
soup = BeautifulSoup(res.text,"html.parser")

aaa="div.newbuild-info.clearfix open-info"
new=soup.select(aaa)
for title in new:
    print(title.text)
