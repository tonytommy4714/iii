# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
table=pd.read_csv(r"C:\Users\asus\Desktop\riii-master\data\eco_index.csv")
table1=pd.read_csv(r"C:\Users\asus\Desktop\riii-master\data\customer.csv")
table2=pd.read_csv(r"C:\Users\asus\Desktop\kkk.csv")

# %%
table.head()
# Out:
#             County   sales  expense  income average
# 0           Taipei  122838    14.83          704024
# 1           Tainan   24689    14.56          430680
# 2  New Taipei City   41719    13.10          506143
# 3        Kaohsiung   41982    11.56          487309
# 4         Taichung   35856    10.56          511603

# %% [markdown]
# barplot

# %%
sns.barplot(x="County",y="income average",data=table)

# %%
table1.head()
# Out:
#    ID  Visit.Time  Average.Expense  Sex  Age
# 0   1           3              5.7    0   10
# 1   2           5             14.5    0   27
# 2   3          16             33.5    0   32
# 3   4           5             15.9    0   30
# 4   5          16             24.9    0   23

# %%
sns.barplot(x="Age",y="Average.Expense",data=table1,hue="Sex",color='blue')#x,y,hue 數據集變量變量名

# %%
set(table3["Type"])
# Out:
# {'公寓', '別墅', '透天厝', '電梯大樓'}

# %%
sns.barplot(x="Type",y="unitPrice",data=table3,hue="Type",order=['公寓', '別墅', '透天厝', '電梯大樓'])
#order 指定欄位排序

# %%
sns.barplot(x="Type",y="unitPrice",data=table3,hue="Type",order=['公寓', '別墅', '透天厝', '電梯大樓'],capsize=0.2 )
#ci 置信區間浮點數或None,capsize可控制ci大小

# %%
sns.barplot(x="Type",y="unitPrice",data=table3,order=['公寓', '別墅', '透天厝', '電梯大樓'],color="red",saturation=0.5 )
#saturation控制設採飽和度

# %%
sns.countplot(x="floorSum", data=table, palette="Greens_d")#根據某一個變數做count

# %%
num
gg=[i for i in table["expense"]]
sns.distplot(gg,hist=False)# distplot要用連續連續數值 #hist=False 不畫中間的bar圖

# %%
sns.distplot(gg,vertical=True)#vertical=True保持水平
# Out:
# c:\users\asus\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.lmplot(x="Visit.Time",y="Average.Expense",data=table1,hue="Sex",palette="muted",size=6)

# %%
sns.stripplot(x="Visit.Time",y="Average.Expense",data=table1,hue="Sex",palette="muted",size=10)

# %%
sns.lmplot(x="floorSum",y="unitPrice",data=table2)

# %%
sns.stripplot(x="Type",y="unitPrice",data=table2,size=8,hue="Type",jitter=True)

# %%
sns.stripplot(x="Visit.Time",y="Average.Expense",data=table1,size=10,hue="Sex",jitter=True,split=True,marker="D")
#jitter,spilt 可以把密集度分開 marker 可以更換圖案樣式
# Out:
# c:\users\asus\appdata\local\programs\python\python36-32\lib\site-packages\seaborn\categorical.py:2586: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(table3,hue="Type")

# %%
sns.boxplot(x="Average.Expense",y="Visit.Time",data=table1)
