# %%
import requests
from bs4 import BeautifulSoup

# %%
a={}
i=1

head=[]
while i<=3: 
    line='http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent'
    page=str(i)
    last='-use/index.html'
    real_link=line+page+last
    res = requests.get( real_link)
    print( real_link)
    soup = BeautifulSoup(res.text,"html.parser")

    block="span.item_title"
    new=soup.select(block)

   
    for title in new:

        head.append(title.text)
       
    i+=1
a['title']=head
address=[]
address1=[]
i=1
while i<=3: 
    line='http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent'
    page=str(i)
    last='-use/index.html'
    real_link=line+page+last
    print( real_link)
    res = requests.get(real_link)
   
    soup = BeautifulSoup(res.text,"html.parser")

    block="span.num-ss"
    new=soup.select(block)

   
    for title in new:

        address.append(title.text)
       
    i+=1

while i<=82:
        for good_adress in address:
            address1.append(good_adress.split())
            i+=1
a['addr']=address1
# Out:
# http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent1-use/index.html
# http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent2-use/index.html
# http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent3-use/index.html
# http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent1-use/index.html
# http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent2-use/index.html
# http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent3-use/index.html

# %%
a
# Out:
# {'title': ['浩瀚星海小套房',
#   '小富邦捷運挑高宅',
#   '光南美套房',
#   '摩宿管理小套房',
#   '水美館很稀有',
#   '台大捷運電梯獨棟',
#   '漢神帝景美套房',
#   '朝代幸福殿堂住辦',
#   '忠孝敦化仁愛學區',
#   '昇陽精緻兩房車位',
#   '河堤國小旁車位',
#   '百吉仁愛豪邸車位',
#   '雅仕小品',
#   'ＹＥＳ世貿高樓層',
#   '台電捷運小資美宅',
#   '世貿高樓邊間套房',
#   'ＡＭＯＵＲ２高樓',
#   '近仁愛路稀有車位',
#   '臺大醫院新屋車位',
#   '忠義街桃花源車位',
#   '光復南路電梯',
#   '雨農精品裝潢美廈',
#   '國家企業大樓車位',
#   '閱禾琚高樓加車位',
#   '美麗大湖陽光滿屋',
#   '寧夏高樓景觀雅軒',
#   '民生挑高可住可辦',
#   '紀念堂挑高管理屋',
#   '中正模範生美套房',
#   '高樓景觀水名錄',
#   '生活機能優美套Ｂ',
#   '生活機能優套房Ａ',
#   '中山北面寬店辦',
#   '忠孝永春捷運店辦',
#   '投資置產１＋２辦',
#   '河堤國小旁車位',
#   '百吉仁愛豪邸車位',
#   '興隆方正店辦',
#   '近仁愛路稀有車位',
#   '臺大醫院新屋車位',
#   '忠義街桃花源車位',
#   '市府捷運雅緻套房',
#   '國家企業大樓車位',
#   '文德港墘旺店辦',
#   '文德港墘金店辦',
#   '文德港墘面寬金店',
#   '合江一樓美居分租',
#   '南港站前小資雅房',
#   '國家大樓１３０坪',
#   '南京揚昇好停車位',
#   '南京揚昇好停車位',
#   '六張犁捷運金店',
#   '近師大便宜大套房',
#   '正中山北路金店面',
#   '師大近捷運套房',
#   '復北長春路金店',
#   '大安路車位７號',
#   '大安路車位６號',
#   '大安森林公園金店',
#   '儒園店辦誠租',
#   '河堤國小旁車位',
#   '百吉仁愛豪邸車位',
#   '近仁愛路稀有車位',
# ...

# %%
address=[]

address1=[]
i=1
while i<=3: 
    line='http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent'
    page=str(i)
    last='-use/index.html'
    real_link=line+page+last
    print( real_link)
    res = requests.get(real_link)
   
    soup = BeautifulSoup(res.text,"html.parser")

    block="span.num-ss"
    new=soup.select(block)

   
    for title in new:

        address.append(title.text)
       
    i+=1

while i<=82:
        for good_adress in address:
            address1.append(good_adress.split())
            i+=1
a['addr']=address1
# Out:
# http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent1-use/index.html
# http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent2-use/index.html
# http://www.sinyi.com.tw/rent/list/Taipei-city/rent3-parking-rent3-use/index.html

# %%
len(address)

while i<=82:
    for good in address:
        good.split()
        
        i+=1
# Out:
# [['金阪神大樓', '/', '台北市文山區景興路'],
#  ['小富邦', '/', '台北市松山區復興北路'],
#  ['台北市大安區光復南路'],
#  ['摩宿', '/', '台北市中山區新生北路二段'],
#  ['台北市中正區寧波西街'],
#  ['台北市大安區泰順街'],
#  ['金阪神大樓', '/', '台北市文山區景興路'],
#  ['朝代、大同世界', '/', '台北市大同區民權西路'],
#  ['台北市大安區敦化南路一段'],
#  ['昇陽GRAND', '/', '台北市大安區光復南路'],
#  ['台北市中正區汀州路二段'],
#  ['台北市大安區仁愛路四段'],
#  ['台北市信義區光復南路'],
#  ['yes世貿', '/', '台北市信義區信義路五段'],
#  ['三穎MORI', '/', '台北市中正區晉江街'],
#  ['yes世貿', '/', '台北市信義區信義路五段'],
#  ['台北市中山區林森北路'],
#  ['台北市中正區林森南路'],
#  ['台北市中正區林森南路'],
#  ['桃花源', '/', '台北市士林區忠義街'],
#  ['翠亨鄉榭', '/', '台北市松山區光復南路'],
#  ['台北市士林區雨農路'],
#  ['台北市松山區南京東路五段'],
#  ['閱禾琚', '/', '台北市中山區建國北路一段'],
#  ['美麗大湖', '/', '台北市內湖區大湖山莊街'],
#  ['台北市大同區寧夏路'],
#  ['廣陽天下', '/', '台北市中山區民生東路三段'],
#  ['台北市中正區羅斯福路一段'],
#  ['台北市中正區南昌一段'],
#  ['台北市中山區明水路'],
#  ['台北市大安區和平東路三段'],
#  ['台北市大安區和平東路三段'],
#  ['台北市中山區中山北路三段'],
#  ['台北市信義區忠孝東路五段'],
#  ['台北市大同區重慶北路二段'],
#  ['台北市中正區汀州路二段'],
#  ['台北市大安區仁愛路四段'],
#  ['台北市文山區興隆路四段'],
#  ['台北市中正區林森南路'],
#  ['台北市中正區林森南路'],
# ...

# %%
addess1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-8329f80d9035> in <module>()
# ----> 1 addess1
#
# NameError: name 'addess1' is not defined
